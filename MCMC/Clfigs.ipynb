# %%
import Clfigs
# %matplotlib inline
reload(Clfigs)
import matplotlib
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)
matplotlib.rcParams['font.size'] = 22

# %%
Clfigs.figs(rel=False,single=True, ylim=6000)

# %%
import matplotlib.pyplot as plt

# %%
plt.xlabel("$C_\ell$"); plt.ylabel("$\ell(\ell+1)C_\ell$")
# Out:
# Text(0,0.5,u'$\\ell(\\ell+1)C_\\ell$')
