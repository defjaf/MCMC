# %%
import os
import sys

sys.path.append(os.environ['HOME']+'/home/proj/stats/MCMC')
os.environ['PYTHONPATH'] = os.environ['HOME']+'/home/proj/stats/MCMC'

# %matplotlib osx
import M31model as m31m
import M31driver as m31d
plottype = 'png'
m31d.plottype = plottype
# Out:
# min Temp = 3.000000 K; max Temp = 100.000000 K
# python version of blackbody

# %% [markdown]
# ### Standard run -- DX9d

# %%
ret_dx9d_1 = m31d.M31(savefig=True, nMC=(20000,100000),random=True, filename='./M31/M31Flux-DX9d.dat')
mcmc_dx9d_1 = ret_dx9d_1[0][1]
# !cp M31_0.png M31_dx9d_1_0a.png
# !cp M31_1.png M31_dx9d_1_1a.png
# Out:
# Object M31
# N_data = 22
# 100%|#########################################################################|
# done with chain 0. naccept=4579 (0.228939)
# per block:  [ 416  149  120  327 1892  885  701   96]
# 100%|#########################################################################|
# 100%|#########################################################################|
# done with chain 1. naccept=35360 (0.353596)
# per block:  [3611 4514 4368 2693 6287 7619 4161 2114]
# chi2 at max = 15.485324
# Max ln likelihood -7.742662 at parameters:
# [  1.19671725e-05   1.61705391e+00   1.84187381e+01   4.48464192e-02
#    2.21447666e+00   1.02743559e+01  -7.72076433e-01   9.75118009e+16]
#           \tau_{250} mean = 1.25432e-05 +- 2.65929e-06
#         \beta_{dust} mean = 1.6219 +- 0.116305
#             T_{dust} mean = 18.3125 +- 0.868194
#                   EM mean = 2.09889 +- 1.30172
#       \Delta T_{CMB} mean = 1.53162 +- 0.911186
#            A_{synch} mean = 9.43408 +- 1.05203
#       \alpha_{synch} mean = -0.927216 +- 0.150667
#              A_{AME} mean = 7.27009e+16 +- 2.84175e+16
# ln Pr of mean = -8.747538
# chi2(mean) = 17.495077

# %%
## run now has wider prior on AME
reload(m31m); reload(m31d)
# %matplotlib osx
ret_dx9d_1 = m31d.M31(savefig=False, nMC=(20000,100000),random=True, filename='./M31/M31Flux-DX9d.dat')
# mcmc_dx9d_1 = ret_dx9d_1[0][1]
# !cp M31_0.png M31_dx9d_1_0a.png
# !cp M31_1.png M31_dx9d_1_1a.png
# Out:
# Object M31
# N_data = 22
# 100%|#########################################################################|
# done with chain 0. naccept=4358 (0.217889)
# per block:  [ 372  159  135  306 1937  803  559   94]
# 100%|#########################################################################|
# 100%|#########################################################################|
# done with chain 1. naccept=34151 (0.341507)
# per block:  [3482 3717 3395 2405 6403 7759 4998 1999]
# chi2 at max = 15.848621
# Max ln likelihood -7.924310 at parameters:
# [  1.23943652e-05   1.62508059e+00   1.82594564e+01   2.43586030e-01
#    1.92795886e+00   9.90771965e+00  -7.47673850e-01   9.19684474e+16]
#           \tau_{250} mean = 1.31619e-05 +- 2.9927e-06
#         \beta_{dust} mean = 1.6459 +- 0.126265
#             T_{dust} mean = 18.1278 +- 0.903137
#                   EM mean = 2.04717 +- 1.62796
#       \Delta T_{CMB} mean = 1.57394 +- 1.07605
#            A_{synch} mean = 9.36401 +- 1.16228
#       \alpha_{synch} mean = -0.919528 +- 0.187848
#              A_{AME} mean = 6.92766e+16 +- 3.53189e+16
# ln Pr of mean = -9.720336
# chi2(mean) = 19.440672

# %% [markdown]
# #### Long chain -- 10^6 points

# %%
ret_dx9d_1e6 = m31d.M31(savefig=True, nMC=(20000,1000000),random=True, filename='./M31/M31Flux-DX9d.dat')
mcmc_dx9d_1e6 = ret_dx9d_1e6[0][1]
# !cp M31_0.png M31_dx9d1e6_1_0a.png
# !cp M31_1.png M31_dx9d1e6_1_1a.png
# Out:
# Object M31
# N_data = 22
# 100%|#########################################################################|
# done with chain 0. naccept=3719 (0.185941)
# per block:  [  99   94  203  307 1913  661  350   99]
# 100%|#########################################################################|
# 100%|#########################################################################|
# done with chain 1. naccept=285745 (0.285745)
# per block:  [51601 22987 12713 30351 28288 75961 35344 28507]
# chi2 at max = 15.520821
# Max ln likelihood -7.760411 at parameters:
# [  1.30915823e-05   1.66501824e+00   1.80276592e+01   3.85185710e-01
#    2.35066489e+00   9.97400267e+00  -7.98299169e-01   9.66062957e+16]
#           \tau_{250} mean = 1.28264e-05 +- 2.76903e-06
#         \beta_{dust} mean = 1.63368 +- 0.127545
#             T_{dust} mean = 18.2402 +- 1.00277
#                   EM mean = 1.80762 +- 1.3311
#       \Delta T_{CMB} mean = 1.65369 +- 1.0258
#            A_{synch} mean = 9.54638 +- 1.07212
#       \alpha_{synch} mean = -0.916499 +- 0.164315
#              A_{AME} mean = 7.70321e+16 +- 3.2826e+16
# ln Pr of mean = -9.090507
# chi2(mean) = 18.181015

# %% [markdown]
# #### Gaussian Prior runs

# %%
m31d.M31model.M31model.set_prior(0.5**-2, 7.7, 0.3**-2, -0.9)
ret_dx9d_p = m31d.M31(savefig=True, nMC=(20000,100000),random=True, filename='./M31/M31Flux-DX9d.dat')
mcmc_dx9d_p= ret_dx9d_p[0][1]
# !cp M31_0.png M31_0_dx9d_p.png
# !cp M31_1.png M31_1_dx9d_p.png
# Out:
# setting EM prior to 7.700000 +- 0.500000
# setting alpha_synch prior to -0.900000 +- 0.300000
# Object M31
# N_data = 22
# 100%|#########################################################################|
# done with chain 0. naccept=4746 (0.237288)
# per block:  [ 273  116  166  286 1906  888 1052   66]
# 100%|#########################################################################|
# 100%|#########################################################################|
# done with chain 1. naccept=44087 (0.440866)
# per block:  [5551 5043 5949 3651 6434 8685 8047  734]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-7c60b50bc26e> in <module>()
#       1 m31d.M31model.M31model.set_prior(0.5**-2, 7.7, 0.3**-2, -0.9)
# ----> 2 ret_dx9d_p = m31d.M31(savefig=True, nMC=(20000,100000),random=True, filename='./M31/M31Flux-DX9d.dat')
#       3 mcmc_dx9d_p= ret_dx9d_p[0][1]
#       4 get_ipython().system(u'cp M31_0.png M31_0_dx9d_p.png')
#       5 get_ipython().system(u'cp M31_1.png M31_1_dx9d_p.png')
#
# /Users/jaffe/home/proj/stats/MCMC/submmSED/M31driver.pyc in M31(rotateParams, start, sigmas, nMC, noPlots, fig0, savefig, retMCMC, fdir, logplot, check, wavelength, doBlock, filename, random, randomrestart)
#      84         lnLike = []
#      85         plt.subplots_adjust(wspace=0.3, hspace=0.25)
# ---> 86         maxlnLike, maxLikeParams = getdist.histgrid(
#      87                                      mcmc[-1], noPlot=noHist, params=np.where(np.array(sigmas)>0)[0],
#      88                                      burn=0.2, stride=1)
#
# AttributeError: 'module' object has no attribute 'histgrid'

# %%
m31d.M31model.M31model.set_prior(0.5**-2, 7.7, 0.3**-2, -0.9)
ret_dx9d_p1e6 = m31d.M31(savefig=True, nMC=(20000,1000000),random=True, filename='./M31/M31Flux-DX9d.dat')
mcmc_dx9d_p1e6= ret_dx9d_p1e6[0][1]
# !cp M31_0.png M31_0_dx9d_p1e6.png
# !cp M31_1.png M31_1_dx9d_p1e6.png

# %% [markdown]
# #### save files and make plots

# %%
# %matplotlib inline
reload(m31m); reload(m31d)
import numpy as np
np.savetxt("MCMC_dx9d_1.dat", mcmc_dx9d_1.samples, header='\t'.join(mcmc_dx9d_1.texNames))
m31m.M31model(*mcmc_dx9d_1.mean()).plot(mcmc_dx9d_1.data[0], wavelength=False, logplot=True, components=True, textfile="MCMC_model_dx9d_1.dat")

np.savetxt("MCMC_dx9d_p.dat", mcmc_dx9d_p.samples, header='\t'.join(mcmc_dx9d_p.texNames))
m31m.M31model(*mcmc_dx9d_p.mean()).plot(mcmc_dx9d_p.data[0], wavelength=False, logplot=True, components=True, textfile="MCMC_model_dx9d_p.dat")

np.savetxt("MCMC_dx9d_1e6.dat", mcmc_dx9d_1e6.samples, header='\t'.join(mcmc_dx9d_1e6.texNames))
m31m.M31model(*mcmc_dx9d_1e6.mean()).plot(mcmc_dx9d_1e6.data[0], wavelength=False, logplot=True, components=True, textfile="MCMC_model_dx9d_1e6.dat")

np.savetxt("MCMC_dx9d_p1e6.dat", mcmc_dx9d_p1e6.samples, header='\t'.join(mcmc_dx9d_p1e6.texNames))
m31m.M31model(*mcmc_dx9d_p1e6.mean()).plot(mcmc_dx9d_p1e6.data[0], wavelength=False, logplot=True, components=True, textfile="MCMC_model_dx9d_p1e6.dat")

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

npar = mcmc_dx9d_1.samples.shape[1]
for i in range(npar):
    plt.subplot(npar, 1, i+1)
    plt.plot(mcmc_dx9d_1.samples[:,i])

# %% [markdown]
# ### DX11d runs

# %%
ret_dx11_1 = m31d.M31(savefig=True, nMC=(20000,100000),random=True, filename='./M31/M31Flux-DX11.dat')
mcmc_dx11_1 = ret_dx11_1[0][1]
# !cp M31_0.png M31_dx11_1_0a.png
# !cp M31_1.png M31_dx11_1_1a.png
# Out:
# Object M31
# N_data = 23
# Number of prior resamples: 2
# 100%|#########################################################################|
# done with chain 0. naccept=7408 (0.370381)
# per block:  [ 539  205  104  372 2050  849  802 2494]
# 100%|#########################################################################|
# 100%|#########################################################################|
# done with chain 1. naccept=53261 (0.532605)
# per block:  [ 4002  5506  5360  4585  6853  8532  6004 12426]
# chi2 at max = 8.572017
# Max ln likelihood -4.286008 at parameters:
# [  1.16940228e-05   1.57564546e+00   1.85471982e+01   5.90284608e+00
#    5.69414539e-02   7.74574805e+00  -1.11082664e+00   1.42127109e+03]
#           \tau_{250} mean = 1.24049e-05 +- 2.38541e-06
#         \beta_{dust} mean = 1.59225 +- 0.117571
#             T_{dust} mean = 18.3678 +- 0.834746
#                   EM mean = 5.38457 +- 1.26254
#       \Delta T_{CMB} mean = 0.0332858 +- 1.01818
#            A_{synch} mean = 7.84399 +- 1.06768
#       \alpha_{synch} mean = -1.0633 +- 0.222997
#              A_{AME} mean = 7921.12 +- 4777.44
# ln Pr of mean = -5.214804
# chi2(mean) = 10.429609

# %%
ret_dx11_2 = m31d.M31(savefig=True, nMC=(20000,100000),random=True, filename='./M31/M31Flux-DX11.dat')
mcmc_dx11_2 = ret_dx11_2[0][1]
# !cp M31_0.png M31_dx11_2_0a.png
# !cp M31_1.png M31_dx11_2_1a.png
# Out:
# Object M31
# N_data = 23
# 100%|#########################################################################|
# done with chain 0. naccept=7541 (0.377031)
# per block:  [ 462  178  120  356 2049  899  984 2500]
# 100%|#########################################################################|
# 100%|#########################################################################|
# done with chain 1. naccept=46045 (0.460445)
# per block:  [ 2967  3801  3277  4385  5212  8228  5698 12484]
# chi2 at max = 8.389222
# Max ln likelihood -4.194611 at parameters:
# [  1.18470990e-05   1.57794540e+00   1.84558212e+01   5.66954032e+00
#   -1.05458793e-01   8.04809666e+00  -1.04716247e+00   5.99469927e+03]
#           \tau_{250} mean = 1.21078e-05 +- 2.57042e-06
#         \beta_{dust} mean = 1.57509 +- 0.12772
#             T_{dust} mean = 18.4966 +- 0.950125
#                   EM mean = 5.39811 +- 1.09405
#       \Delta T_{CMB} mean = -0.0591941 +- 1.0242
#            A_{synch} mean = 7.83895 +- 1.03455
#       \alpha_{synch} mean = -1.05586 +- 0.224978
#              A_{AME} mean = 27598.2 +- 15456.3
# ln Pr of mean = -5.210553
# chi2(mean) = 10.421106

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

npar = mcmc_dx9d_1.samples.shape[1]
for i in range(npar):
    plt.subplot(npar, 1, i+1)
    plt.plot(mcmc_dx11_2.samples[:,i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-efddc3b74bfd> in <module>()
#       6 for i in range(npar):
#       7     plt.subplot(npar, 1, i+1)
# ----> 8     plt.plot(mcmc_dx11_2.samples[:,i])
#
# NameError: name 'mcmc_dx11_2' is not defined

# %%
# %store mcmc_dx9d_1
# %store mcmc_dx9d_2

# %store mcmc_dx11_1
# %store mcmc_dx11_2


### should store -d these later

# %%
# %matplotlib inline

# %%
reload(m31m); reload(m31d)
import numpy as np
np.savetxt("MCMC_dx9d_1.dat", mcmc_dx9d_1.samples, header='\t'.join(mcmc_dx9d_1.texNames))
m31m.M31model(*mcmc_dx9d_1.mean()).plot(mcmc_dx9d_1.data[0], wavelength=False, logplot=True, components=True, textfile="MCMC_model_dx9d_1.dat")

np.savetxt("MCMC_dx9d_2.dat", mcmc_dx9d_2.samples, header='\t'.join(mcmc_dx9d_2.texNames))
m31m.M31model(*mcmc_dx9d_2.mean()).plot(mcmc_dx9d_2.data[0], wavelength=False, logplot=True, components=True, textfile="MCMC_model_dx9d_2.dat")

np.savetxt("MCMC_dx11_1.dat", mcmc_dx11_1.samples, header='\t'.join(mcmc_dx11_1.texNames))
m31m.M31model(*mcmc_dx11_1.mean()).plot(mcmc_dx11_1.data[0], wavelength=False, logplot=True, components=True, textfile="MCMC_model_dx11_1.dat")

np.savetxt("MCMC_dx11_2.dat", mcmc_dx11_2.samples, header='\t'.join(mcmc_dx11_2.texNames))
m31m.M31model(*mcmc_dx11_2.mean()).plot(mcmc_dx11_2.data[0], wavelength=False, logplot=True, components=True, textfile="MCMC_model_dx11_2.dat")

# %%
m31d.M31model.M31model.set_prior(0.5**-2, 7.7, 0.3**-2, -0.9)
ret_x = m31d.M31(savefig=True, nMC=(20000,100000),random=True)
mcmc_x = ret_x[0][1]
# !cp M31_0.png M31_0x.png
# !cp M31_1.png M31_1x.png
# Out:
# setting EM prior to 7.700000 +- 0.500000
# setting alpha_synch prior to -0.900000 +- 0.300000
# Object M31
# N_data = 24
# done with chain 0. naccept=7569 (0.378431)
# 100% |########################################################################|
# 100% |########################################################################|
# per block:  [ 389  166  145  349 2073 1226  782 2446]
# done with chain 1. naccept=54853 (0.548525)
# per block:  [ 3163  4205  4096  6934  6929  9065  7999 12469]
# chi2 at max = 22.104815
# Max ln likelihood -11.920782 at parameters:
# 100% |########################################################################|
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-20-0d2c4da05949> in <module>()
#       1 m31d.M31model.M31model.set_prior(0.5**-2, 7.7, 0.3**-2, -0.9)
# ----> 2 ret_x = m31d.M31(savefig=True, nMC=(20000,100000),random=True)
#       3 mcmc_x = ret_x[0][1]
#       4 get_ipython().system(u'cp M31_0.png M31_0x.png')
#       5 get_ipython().system(u'cp M31_1.png M31_1x.png')
#
# /Users/jaffe/home/proj/stats/MCMC/submmSED/M31driver.pyc in M31(rotateParams, start, sigmas, nMC, noPlots, fig0, savefig, retMCMC, fdir, logplot, check, wavelength, doBlock, random, randomrestart)
#      85         maxlnLike, maxLikeParams = getdist.histgrid(
#      86                                      mcmc[-1], noPlot=noHist, params=np.where(np.array(sigmas)>0)[0],
# ---> 87                                      burn=0.2, stride=1)
#      88         plt.subplots_adjust()
#      89
#
# /Users/jaffe/home/proj/stats/MCMC/getdist.pyc in histgrid(MCMC, params, nbins, labels, lnLike, quiet, derived, maxlnLike, noPlot, burn, stride)
#     193         print 'Max ln likelihood %f at parameters:' % maxlnLike
#     194         assert abs(1.-maxLProb/maxlnLike)<0.01, \
# --> 195             "different likelihood calculations differ: %f != %f" % (maxLProb,maxlnLike)
#     196         print maxLikeParams
#     197
#
# AssertionError: different likelihood calculations differ: -11.052408 != -11.920782

# %%
m31d.M31model.M31model.set_prior(0, 7.7, 0, -0.9)
ret_y = m31d.M31(savefig=True, nMC=(20000,100000),random=True)
mcmc_y = ret_y[0][1]
# !cp M31_0.png M31_0y.png
# !cp M31_1.png M31_1y.png

# %%
# %pylab inline
np.savetxt("MCMC_x.dat", mcmc_x.samples, header='\t'.join(mcmc_x.texNames))
m31m.M31model(*mcmc_x.mean()).plot(mcmc_x.data[0], wavelength=False, logplot=True, components=True, textfile="MCMC_model_x.dat")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-f64974e371e2> in <module>()
#       1 get_ipython().magic(u'pylab inline')
# ----> 2 np.savetxt("MCMC_x.dat", mcmc_x.samples, header='\t'.join(mcmc_x.texNames))
#       3 m31m.M31model(*mcmc_x.mean()).plot(mcmc_x.data[0], wavelength=False, logplot=True, components=True, textfile="MCMC_model_x.dat")
#
# NameError: name 'mcmc_x' is not defined

# %%
plt.savefig?

# %%
# %matplotlib?

# %%
m31m.AME(90.0)
# Out:
# 6.7062767770014192e-20

# %%
m31m.synch(1, 90.0)
# Out:
# 90.0
