# %%
# %matplotlib inline
from __future__ import print_function
from getdist import plots, MCSamples
import getdist, IPython
reload(getdist)print('Version: ',getdist.__version__)

# %%
import numpy as np
ndim = 4
nsamp = 10000
np.random.seed(10)
A = np.random.rand(ndim,ndim)
cov = np.dot(A, A.T)
samps = np.random.multivariate_normal([0]*ndim, cov, size=nsamp)
A = np.random.rand(ndim,ndim)
cov = np.dot(A, A.T)
samps2 = np.random.multivariate_normal([0]*ndim, cov, size=nsamp)

# %%
names = ["x%s"%i for i in range(ndim)]
labels =  ["x_%s"%i for i in range(ndim)]
samples = MCSamples(samples=samps,names = names, labels = labels)
samples2 = MCSamples(samples=samps2,names = names, labels = labels)

# %%
#Triangle plot
g = plots.getSinglePlotter(width_inch=4, ratio=1)
g.plot_2d([samples, samples2], 'x1', 'x2')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-45ae66277dc9> in <module>()
#       1 #Triangle plot
#       2 g = plots.getSinglePlotter(width_inch=4, ratio=1)
# ----> 3 g.plot_2d([samples, samples2], 'x1', 'x2')
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/getdist/plots.pyc in plot_2d(self, roots, param1, param2, param_pair, shaded, add_legend_proxy, line_offset, proxy_root_exclude, **kwargs)
#    1066             res = self.add_2d_contours(root, param_pair[0], param_pair[1], line_offset + i, of=len(roots),
#    1067                                        add_legend_proxy=add_legend_proxy and not root in proxy_root_exclude,
# -> 1068                                        **contour_args[i])
#    1069             xbounds, ybounds = self._updateLimits(res, xbounds, ybounds)
#    1070         if xbounds is None: return
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/getdist/plots.pyc in add_2d_contours(self, root, param1, param2, plotno, of, cols, contour_levels, add_legend_proxy, param_pair, density, alpha, ax, **kwargs)
#     906             kwargs['alpha'] = alpha
#     907             CS = ax.contour(density.x, density.y, density.P, contour_levels, colors=cols, linestyles=linestyles,
# --> 908                             linewidths=self.settings.lw_contour, **kwargs)
#     909             dashes = args.get('dashes')
#     910             if dashes:
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in contour(self, *args, **kwargs)
#    5642             self.cla()
#    5643         kwargs['filled'] = False
# -> 5644         return mcontour.QuadContourSet(self, *args, **kwargs)
#    5645     contour.__doc__ = mcontour.QuadContourSet.contour_doc
#    5646
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/contour.pyc in __init__(self, ax, *args, **kwargs)
#    1422         are described in QuadContourSet.contour_doc.
#    1423         """
# -> 1424         ContourSet.__init__(self, ax, *args, **kwargs)
#    1425
#    1426     def _process_args(self, *args, **kwargs):
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/contour.pyc in __init__(self, ax, *args, **kwargs)
#     861         self._transform = kwargs.get('transform', None)
#     862
# --> 863         self._process_args(*args, **kwargs)
#     864         self._process_levels()
#     865
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/contour.pyc in _process_args(self, *args, **kwargs)
#    1443                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1444
# -> 1445             x, y, z = self._contour_args(args, kwargs)
#    1446
#    1447             _mask = ma.getmask(z)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/contour.pyc in _contour_args(self, args, kwargs)
#    1538             warnings.warn('Log scale: values of z <= 0 have been masked')
#    1539             self.zmin = z.min()
# -> 1540         self._contour_level_args(z, args)
#    1541         return (x, y, z)
#    1542
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/contour.pyc in _contour_level_args(self, z, args)
#    1187                 warnings.warn("Contour levels are not increasing")
#    1188             else:
# -> 1189                 raise ValueError("Contour levels must be increasing")
#    1190
#    1191     def _process_levels(self):
#
# ValueError: Contour levels must be increasing

# %%
samples

# %%
# %debug
# Out:
# > /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/contour.py(1189)_contour_level_args()
#    1187                 warnings.warn("Contour levels are not increasing")
#    1188             else:
# -> 1189                 raise ValueError("Contour levels must be increasing")
#    1190
#    1191     def _process_levels(self):
#
# ipdb> up
# > /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/contour.py(1540)_contour_args()
#    1538             warnings.warn('Log scale: values of z <= 0 have been masked')
#    1539             self.zmin = z.min()
# -> 1540         self._contour_level_args(z, args)
#    1541         return (x, y, z)
#    1542
#
# ipdb> print(z)
# [[2.9230272710922193e-05 3.3617528491344336e-05 3.7458230613994704e-05 ...,
#   1.391625898292481e-31 1.5241834191870755e-31 1.685926495412218e-31]
#  [3.101191033557031e-05 3.664790589813878e-05 4.197186583209261e-05 ...,
#   6.317260678932864e-32 6.855294781814663e-32 7.758868674194953e-32]
#  [3.1891847580826776e-05 3.8719968115297326e-05 4.557054453910019e-05 ...,
#   3.1214417603926536e-32 3.274459195388466e-32 3.351005136757682e-32]
#  ...,
#  [-1.258376824538292e-33 -7.316380133388989e-34 -5.6863722584886705e-34
#   ..., 1.5289740788572813e-07 2.0075587064924716e-07 2.540613908778987e-07]
#  [6.716688862962765e-33 4.4845003224647266e-33 5.2522717020915406e-33 ...,
#   8.35894753624009e-08 1.135516672414752e-07 1.4866635069012204e-07]
#  [8.672399611769518e-32 7.695291428883891e-32 6.941521119581555e-32 ...,
#   3.1596541578424364e-33 2.7335872648025888e-33 1.941792119942122e-33]]
# ipdb> print args
# (array([ 0.32505883,  0.05072845]),)
# ipdb> up
# > /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/contour.py(1445)_process_args()
#    1443                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1444
# -> 1445             x, y, z = self._contour_args(args, kwargs)
#    1446
#    1447             _mask = ma.getmask(z)
#
# ipdb> up
# > /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/contour.py(863)__init__()
#     861         self._transform = kwargs.get('transform', None)
#     862
# --> 863         self._process_args(*args, **kwargs)
#     864         self._process_levels()
#     865
#
# ipdb> up
# > /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/contour.py(1424)__init__()
#    1422         are described in QuadContourSet.contour_doc.
#    1423         """
# -> 1424         ContourSet.__init__(self, ax, *args, **kwargs)
#    1425
#    1426     def _process_args(self, *args, **kwargs):
#
# ipdb> up
# > /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/axes/_axes.py(5644)contour()
#    5642             self.cla()
#    5643         kwargs['filled'] = False
# -> 5644         return mcontour.QuadContourSet(self, *args, **kwargs)
#    5645     contour.__doc__ = mcontour.QuadContourSet.contour_doc
#    5646
#
# ipdb> up
# > /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/__init__.py(1812)inner()
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# ipdb> up
# > /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/getdist/plots.py(908)add_2d_contours()
#     906             kwargs['alpha'] = alpha
#     907             CS = ax.contour(density.x, density.y, density.P, contour_levels, colors=cols, linestyles=linestyles,
# --> 908                             linewidths=self.settings.lw_contour, **kwargs)
#     909             dashes = args.get('dashes')
#     910             if dashes:
#
# ipdb> up
# > /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/getdist/plots.py(1068)plot_2d()
#    1066             res = self.add_2d_contours(root, param_pair[0], param_pair[1], line_offset + i, of=len(roots),
#    1067                                        add_legend_proxy=add_legend_proxy and not root in proxy_root_exclude,
# -> 1068                                        **contour_args[i])
#    1069             xbounds, ybounds = self._updateLimits(res, xbounds, ybounds)
#    1070         if xbounds is None: return
#
# ipdb> print contour_args[i]
# {'filled': False}
# ipdb> print root
# <getdist.mcsamples.MCSamples object at 0x106802650>
# ipdb> down
# > /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/getdist/plots.py(908)add_2d_contours()
#     906             kwargs['alpha'] = alpha
#     907             CS = ax.contour(density.x, density.y, density.P, contour_levels, colors=cols, linestyles=linestyles,
# --> 908                             linewidths=self.settings.lw_contour, **kwargs)
#     909             dashes = args.get('dashes')
#     910             if dashes:
#
# ipdb> print contour_levels
# [ 0.32505883  0.05072845]
# ipdb> print density
# <getdist.densities.Density2D object at 0x10df1f490>
# ipdb> print density.levels
# *** AttributeError: 'Density2D' object has no attribute 'levels'
# ipdb> print levels
# *** NameError: name 'levels' is not defined
# ipdb> up
# > /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/getdist/plots.py(1068)plot_2d()
#    1066             res = self.add_2d_contours(root, param_pair[0], param_pair[1], line_offset + i, of=len(roots),
#    1067                                        add_legend_proxy=add_legend_proxy and not root in proxy_root_exclude,
# -> 1068                                        **contour_args[i])
#    1069             xbounds, ybounds = self._updateLimits(res, xbounds, ybounds)
#    1070         if xbounds is None: return
#
# ipdb> down
# > /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/getdist/plots.py(908)add_2d_contours()
#     906             kwargs['alpha'] = alpha
#     907             CS = ax.contour(density.x, density.y, density.P, contour_levels, colors=cols, linestyles=linestyles,
# --> 908                             linewidths=self.settings.lw_contour, **kwargs)
#     909             dashes = args.get('dashes')
#     910             if dashes:
#
# ipdb> print contour_levels
# [ 0.32505883  0.05072845]
